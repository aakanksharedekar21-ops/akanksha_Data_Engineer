# %%
# %sql
truncate table new_catlog.intellibi_bronze.monthly_sales;
truncate table new_catlog.intellibi_silver.fmonthly_sales;
truncate table new_catlog.intellibi_gold.fmonthlysales;

# %%
# %sql
select count(*) from new_catlog.intellibi_bronze.monthly_sales

# %%
# %sql

select count(*) from new_catlog.intellibi_silver.fmonthly_sales

# %%
# %sql

select count(*) from new_catlog.intellibi_gold.fmonthlysales
