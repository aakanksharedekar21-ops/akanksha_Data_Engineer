-- %%
Create or replace table new_catlog.intellibi_bronze.rawCustomer 
( 
    customer_id string, 
    customer_name string, 
    email string,
    phone string,
    address string,
    city string,
    state string,
    country string,
    zip_code string,
    segment string,
    ingest_ts timestamp
)

select * from new_catlog.intellibi_bronze.rawCustomer
