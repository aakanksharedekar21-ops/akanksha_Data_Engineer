# %%
dfDiscount = spark.read.option("inferSchema", "false") \
    .option("header", "true") \
    .csv("/Volumes/saleslake_dev/bronze_dev/vol_saleslake_src_files_dev/daily_discount/")

dfDiscount.display()

# /Volumes/saleslake_dev/bronze_dev/vol_saleslake_src_files_dev/daily_discount/

# %%
dfDiscount.write.mode("append").saveAsTable("saleslake_dev.bronze_dev.raeDiscount")

# %%
srcLoc = '/Volumes/saleslake_dev/bronze_dev/vol_saleslake_src_files_dev/daily_discount/'
arcLoc = '/Volumes/saleslake_dev/bronze_dev/vol_saleslake_archive_files_dev/daily_discount/'

listofFiles= dbutils.fs.ls(srcLoc)
print(listofFiles)


for file in listofFiles:
    print(file.name)
    print(file.path)
    print(file.size)

# %%
for file in listofFiles:
    print (file.name)
    if file.name.endswith('.csv'):
        dbutils.fs.mv(srcLoc+file.name,arcLoc+file.name)

# %%
# %sql
SHOW VOLUMES;

# %%
dbutils.fs.cp -----> copy the file from one location to another
dbutils.fs.rm -----> remove the file from the location
dbutils.fs.ls -----> list the file from the location
dbutils.fs.head -----> head the file from the location
dbutils.fs.mkdirs -----> make the directory
