-- %%
create or replace table new_catlog.intellibi_bronze.rawmonthly_sales
(
    sale_id string,
    product string,
    category string,
    quantity string,
    price string,
    sale_date string,
    region string,
    ingest_ts timestamp
);

select * from new_catlog.intellibi_bronze.rawmonthly_sales

drop table new_catlog.intellibi_bronze.monthly_sales;
