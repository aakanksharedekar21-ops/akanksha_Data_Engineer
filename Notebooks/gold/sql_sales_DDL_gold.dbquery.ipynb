-- %%
create or replace table new_catlog.intellibi_gold.Refinedmonthly_sales
(
    sale_id integer,
    product string,
    category string,
    quantity integer,
    price double,
    sale_date date,
    region string,
    ingest_load_ts timestamp,
    last_updt_ts timestamp
);

select * from new_catlog.intellibi_silver.cleansedmonthly_sales

select * from new_catlog.intellibi_gold.Refinedmonthly_sales
