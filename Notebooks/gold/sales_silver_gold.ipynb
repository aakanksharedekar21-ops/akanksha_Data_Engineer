# %%
# %sql
# create table new_catlog.intellibi_gold.fmonthlysales
# as
# select * from new_catlog.intellibi_silver.fmonthly_sales where 1=2;

# %%
# %sql
MERGE INTO new_catlog.intellibi_gold.fmonthlysales
USING new_catlog.intellibi_silver.fmonthly_sales
ON new_catlog.intellibi_gold.fmonthlysales.sale_id = new_catlog.intellibi_silver.fmonthly_sales.sale_id

WHEN MATCHED THEN UPDATE SET *
WHEN NOT MATCHED THEN INSERT *
;

# %%
# %sql 
select * from new_catlog.intellibi_gold.fmonthlysales;
