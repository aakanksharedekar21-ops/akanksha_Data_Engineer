-- %%
Create or replace table new_catlog.intellibi_silver.cleansedCustomer 
( 
    customer_id int, 
    customer_name string, 
    email string,
    phone string,
    address string,
    city string,
    state string,
    country string,
    zip_code string,
    segment string,
    ingest_ts timestamp
)

select * from new_catlog.intellibi_silver.cleansedCustomer
