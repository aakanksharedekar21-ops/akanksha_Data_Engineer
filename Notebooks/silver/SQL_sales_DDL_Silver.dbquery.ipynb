-- %%
create or replace table new_catlog.intellibi_silver.cleansedmonthly_sales
(
    sale_id integer,
    product string,
    category string,
    quantity integer,
    price double,
    sale_date date,
    region string,
    ingest_ts timestamp
);

select * from new_catlog.intellibi_silver.cleansedmonthly_sales

describe new_catlog.intellibi_silver.cleansedmonthly_sales;

drop table new_catlog.intellibi_bronze.monthly_sales;

truncate table new_catlog.intellibi_silver.cleansedmonthly_sales;

drop table new_catlog.intellibi_silver.cleansedmonthly_sales
