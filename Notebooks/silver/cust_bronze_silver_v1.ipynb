# %%
# %sql
insert into new_catlog.intellibi_silver.cleansedcustomer 
select distinct
 CAST(TRIM(customer_id) AS INTEGER) as customer_id ,
    UPPER(TRIM(customer_name)) as customer_name,
    UPPER(TRIM(email)) as email,
    UPPER(TRIM(phone)) as phone,
    UPPER(TRIM(address)) as address,
    UPPER(TRIM(city)) as city,
    UPPER(TRIM(state)) as state,
    UPPER(TRIM(country)) as country,
    UPPER(TRIM(zip_code)) as zip_code,
    UPPER(TRIM(segment)) as region,
    CURRENT_TIMESTAMP() as ingest_ts
from new_catlog.intellibi_bronze.rawcustomer

where ingest_ts > (select coalesce(max(ingest_ts), to_date('1900-01-01','yyyy-MM-dd')) from new_catlog.intellibi_silver.cleansedcustomer)
order by cast(trim(customer_id)as integer);

# %%
# %sql
# select * from new_catlog.intellibi_bronze.monthly_sales

# %%
# %sql
# select * from new_catlog.intellibi_silver.fmonthly_sales
