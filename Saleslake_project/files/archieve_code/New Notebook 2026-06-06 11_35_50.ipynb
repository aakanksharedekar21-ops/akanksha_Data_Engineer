# %%
# %sql

SELECT COUNT(*) FROM saleslake_dev.bronze_dev.rawdiscount;
SELECT COUNT(*) FROM saleslake_dev.bronze_dev.rawinvoice;
SELECT COUNT(*) FROM saleslake_dev.bronze_dev.rawproduct;
SELECT COUNT(*) FROM saleslake_dev.bronze_dev.rawregion;
SELECT COUNT(*) FROM saleslake_dev.bronze_dev.rawstore;
SELECT COUNT(*) FROM saleslake_dev.bronze_dev.rawsales;
SELECT COUNT(*) FROM saleslake_dev.bronze_dev.rawcustomer;


SELECT COUNT(*) FROM saleslake_dev.gold_dev.dim_discount;
SELECT COUNT(*) FROM saleslake_dev.gold_dev.refinedcustomer;
SELECT COUNT(*) FROM saleslake_dev.gold_dev.dim_product;
SELECT COUNT(*) FROM saleslake_dev.gold_dev.dim_region;
SELECT COUNT(*) FROM saleslake_dev.gold_dev.refinedInvoice;
SELECT COUNT(*) FROM saleslake_dev.gold_dev.dim_store;
SELECT COUNT(*) FROM saleslake_dev.gold_dev.refinedsales;
SELECT COUNT(*) FROM saleslake_dev.gold_dev.fact_invoice;
SELECT COUNT(*) FROM saleslake_dev.gold_dev.fact_sales;

# %%
# %sql
SELECT COUNT(*) AS cleaneddiscount_count
FROM saleslake_dev.silver_dev.cleaneddiscount;

# %%
# %sql

SELECT COUNT(*) AS cleanedinvoice_count
FROM saleslake_dev.silver_dev.cleanedinvoice;

# %%
# %sql

SELECT COUNT(*) AS cleanedproduct_count
FROM saleslake_dev.silver_dev.cleanedproduct;

# %%
# %sql

-- SELECT COUNT(*) AS cleanedregion_count
-- FROM saleslake_dev.silver_dev.cleanedregion;

-- SELECT COUNT(*) AS cleanedstore_count
-- FROM saleslake_dev.silver_dev.cleanedstore;

-- SELECT COUNT(*) AS cleanedcustomer_count
-- FROM saleslake_dev.silver_dev.cleanedcustomer;

SELECT COUNT(*) AS cleanedsales_count
FROM saleslake_dev.silver_dev.cleanedsales;
