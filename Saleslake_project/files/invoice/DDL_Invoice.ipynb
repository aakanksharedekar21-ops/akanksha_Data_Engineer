# %%
# %sql
-- ===== EXISTING: rawInvoice  (external; already on AWS S3) =====
CREATE TABLE IF NOT EXISTS saleslake_dev.bronze_dev.rawInvoice (
    invoice_id STRING, invoice_number STRING, customer_id STRING,
    invoice_date STRING, due_date STRING,
    subtotal_amount STRING, discount_code STRING, discount_amount STRING,
    tax_amount STRING, total_amount STRING,
    payment_status STRING, payment_method STRING, payment_date STRING,
    currency STRING, region STRING, store_id STRING, channel STRING,
    created_by STRING,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-2111-eu-north-1/saleslake/dev/bronze_delta_tables/invoice/';

CREATE TABLE IF NOT EXISTS saleslake_qa.bronze_qa.rawInvoice (
    invoice_id STRING, invoice_number STRING, customer_id STRING,
    invoice_date STRING, due_date STRING,
    subtotal_amount STRING, discount_code STRING, discount_amount STRING,
    tax_amount STRING, total_amount STRING,
    payment_status STRING, payment_method STRING, payment_date STRING,
    currency STRING, region STRING, store_id STRING, channel STRING,
    created_by STRING,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-2111-eu-north-1/saleslake/qa/bronze_delta_table/invoice/';

CREATE TABLE IF NOT EXISTS saleslake_prd.bronze_prd.rawInvoice (
    invoice_id STRING, invoice_number STRING, customer_id STRING,
    invoice_date STRING, due_date STRING,
    subtotal_amount STRING, discount_code STRING, discount_amount STRING,
    tax_amount STRING, total_amount STRING,
    payment_status STRING, payment_method STRING, payment_date STRING,
    currency STRING, region STRING, store_id STRING, channel STRING,
    created_by STRING,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-2111-eu-north-1/saleslake/prd/bronze_delta_tables/invoice/';

# %%
# %sql
-- ===== EXISTING: cleanedInvoice  (external on AWS S3) =====
CREATE TABLE IF NOT EXISTS saleslake_dev.silver_dev.cleanedInvoice (
    invoice_id STRING NOT NULL, invoice_number STRING,
    customer_id BIGINT, invoice_date DATE, due_date DATE,
    subtotal_amount DECIMAL(18,2), discount_code STRING,
    discount_amount DECIMAL(18,2), tax_amount DECIMAL(18,2),
    total_amount DECIMAL(18,2),
    payment_status STRING, payment_method STRING, payment_date DATE,
    currency STRING, region STRING, store_id STRING, channel STRING,
    created_by STRING,
    ingest_ts TIMESTAMP NOT NULL
)
USING DELTA
LOCATION 's3://saleslake-2111-eu-north-1/saleslake/dev/silver_delta_tables/invoice/';

CREATE TABLE IF NOT EXISTS saleslake_qa.silver_qa.cleanedInvoice (
    invoice_id STRING NOT NULL, invoice_number STRING,
    customer_id BIGINT, invoice_date DATE, due_date DATE,
    subtotal_amount DECIMAL(18,2), discount_code STRING,
    discount_amount DECIMAL(18,2), tax_amount DECIMAL(18,2),
    total_amount DECIMAL(18,2),
    payment_status STRING, payment_method STRING, payment_date DATE,
    currency STRING, region STRING, store_id STRING, channel STRING,
    created_by STRING,
    ingest_ts TIMESTAMP NOT NULL
)
USING DELTA
LOCATION 's3://saleslake-2111-eu-north-1/saleslake/qa/silver_delta_table/invoice/';

CREATE TABLE IF NOT EXISTS saleslake_prd.silver_prd.cleanedInvoice (
    invoice_id STRING NOT NULL, invoice_number STRING,
    customer_id BIGINT, invoice_date DATE, due_date DATE,
    subtotal_amount DECIMAL(18,2), discount_code STRING,
    discount_amount DECIMAL(18,2), tax_amount DECIMAL(18,2),
    total_amount DECIMAL(18,2),
    payment_status STRING, payment_method STRING, payment_date DATE,
    currency STRING, region STRING, store_id STRING, channel STRING,
    created_by STRING,
    ingest_ts TIMESTAMP NOT NULL
)
USING DELTA
LOCATION 's3://saleslake-2111-eu-north-1/saleslake/prd/silver_delta_tables/invoice/';

# %%
# %sql

-- DROP TABLE saleslake_dev.gold_dev.dim_invoice;
-- DROP TABLE saleslake_qa.gold_qa.dim_invoice;
-- DROP TABLE saleslake_prd.gold_prd.dim_invoice;
-- ===== EXISTING: refinedInvoice  (external on AWS S3) =====
CREATE TABLE IF NOT EXISTS saleslake_dev.gold_dev.refinedInvoice (
    invoice_id STRING NOT NULL, invoice_number STRING,
    customer_id BIGINT, invoice_date DATE, due_date DATE,
    subtotal_amount DECIMAL(18,2), discount_code STRING,
    discount_amount DECIMAL(18,2), tax_amount DECIMAL(18,2),
    total_amount DECIMAL(18,2),
    payment_status STRING, payment_method STRING, payment_date DATE,
    currency STRING, region STRING, store_id STRING, channel STRING,
    created_by STRING,
    initial_load_ts TIMESTAMP NOT NULL, last_updt_ts TIMESTAMP NOT NULL,
    is_active STRING,
    rec_version INT,
    start_effective_ts TIMESTAMP,
    end_effective_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-2111-eu-north-1/saleslake/dev/gold_delta_tables/invoice/';

CREATE TABLE IF NOT EXISTS saleslake_qa.gold_qa.refinedInvoice (
    invoice_id STRING NOT NULL, invoice_number STRING,
    customer_id BIGINT, invoice_date DATE, due_date DATE,
    subtotal_amount DECIMAL(18,2), discount_code STRING,
    discount_amount DECIMAL(18,2), tax_amount DECIMAL(18,2),
    total_amount DECIMAL(18,2),
    payment_status STRING, payment_method STRING, payment_date DATE,
    currency STRING, region STRING, store_id STRING, channel STRING,
    created_by STRING,
    initial_load_ts TIMESTAMP NOT NULL, last_updt_ts TIMESTAMP NOT NULL,
    is_active STRING,
    rec_version INT,
    start_effective_ts TIMESTAMP,
    end_effective_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-2111-eu-north-1/saleslake/qa/gold_delta_table/invoice/';

CREATE TABLE IF NOT EXISTS saleslake_prd.gold_prd.refinedInvoice (
    invoice_id STRING NOT NULL, invoice_number STRING,
    customer_id BIGINT, invoice_date DATE, due_date DATE,
    subtotal_amount DECIMAL(18,2), discount_code STRING,
    discount_amount DECIMAL(18,2), tax_amount DECIMAL(18,2),
    total_amount DECIMAL(18,2),
    payment_status STRING, payment_method STRING, payment_date DATE,
    currency STRING, region STRING, store_id STRING, channel STRING,
    created_by STRING,
    initial_load_ts TIMESTAMP NOT NULL, last_updt_ts TIMESTAMP NOT NULL,
    is_active STRING,
    rec_version INT,
    start_effective_ts TIMESTAMP,
    end_effective_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-2111-eu-north-1/saleslake/prd/gold_delta_table/invoice/';

# %%
# %sql
-- drop table saleslake_qa.gold_qa.refinedInvoice
-- drop table saleslake_prd.gold_prd.refinedInvoice
drop table saleslake_dev.gold_dev.refinedInvoice

# %%
# %sql

ALTER TABLE saleslake_dev.gold_dev.refinedInvoice ADD COLUMNS (
    is_active STRING,
    rec_version INT,
    start_effective_ts TIMESTAMP,
    end_effective_ts TIMESTAMP
);

# %%
# %sql

ALTER TABLE saleslake_qa.gold_qa.refinedInvoice ADD COLUMNS (
    is_active STRING,
    rec_version INT,
    start_effective_ts TIMESTAMP,
    end_effective_ts TIMESTAMP
);

# %%
# %sql

ALTER TABLE saleslake_prd.gold_prd.refinedInvoice ADD COLUMNS (
    is_active STRING,
    rec_version INT,
    start_effective_ts TIMESTAMP,
    end_effective_ts TIMESTAMP
);
