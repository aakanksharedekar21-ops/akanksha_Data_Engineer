# %%
# %sql
-- ===== EXISTING: rawDiscount  (managed table) =====
CREATE TABLE IF NOT EXISTS saleslake_dev.bronze_dev.rawDiscount (
    discount_id STRING, discount_code STRING, discount_name STRING,
    discount_type STRING, discount_value STRING,
    min_purchase_amount STRING, max_discount_amount STRING,
    valid_from STRING, valid_to STRING,
    applicable_segment STRING, applicable_category STRING,
    usage_limit_per_customer STRING, total_usage_limit STRING,
    is_active STRING, created_date STRING,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION  's3://saleslake-2111-eu-north-1/saleslake/dev/bronze_delta_tables/discount';

CREATE TABLE IF NOT EXISTS saleslake_qa.bronze_qa.rawDiscount (
    discount_id STRING, discount_code STRING, discount_name STRING,
    discount_type STRING, discount_value STRING,
    min_purchase_amount STRING, max_discount_amount STRING,
    valid_from STRING, valid_to STRING,
    applicable_segment STRING, applicable_category STRING,
    usage_limit_per_customer STRING, total_usage_limit STRING,
    is_active STRING, created_date STRING,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-2111-eu-north-1/saleslake/qa/bronze_delta_tables/discount';

CREATE TABLE IF NOT EXISTS saleslake_prd.bronze_prd.rawDiscount (
    discount_id STRING, discount_code STRING, discount_name STRING,
    discount_type STRING, discount_value STRING,
    min_purchase_amount STRING, max_discount_amount STRING,
    valid_from STRING, valid_to STRING,
    applicable_segment STRING, applicable_category STRING,
    usage_limit_per_customer STRING, total_usage_limit STRING,
    is_active STRING, created_date STRING,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-2111-eu-north-1/saleslake/prd/bronze_delta_tables/discount';

# %%
# %sql
-- drop table saleslake_dev.bronze_dev.rawDiscount
-- drop table saleslake_qa.bronze_qa.rawDiscount 
drop table saleslake_prd.bronze_prd.rawDiscount

# %%
# %sql
-- ===== NEW: cleanedDiscount  (external on AWS S3) =====
CREATE TABLE IF NOT EXISTS saleslake_dev.silver_dev.cleanedDiscount (
    discount_id INT, discount_code STRING, discount_name STRING,
    discount_type STRING, discount_value DECIMAL(10,2),
    min_purchase_amount DECIMAL(18,2), max_discount_amount DECIMAL(18,2),
    valid_from DATE, valid_to DATE,
    applicable_segment STRING, applicable_category STRING,
    usage_limit_per_customer INT, total_usage_limit INT,
    is_active STRING, created_date DATE,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-2111-eu-north-1/saleslake/dev/silver_delta_tables/discount/';

CREATE TABLE IF NOT EXISTS saleslake_qa.silver_qa.cleanedDiscount (
    discount_id INT, discount_code STRING, discount_name STRING,
    discount_type STRING, discount_value DECIMAL(10,2),
    min_purchase_amount DECIMAL(18,2), max_discount_amount DECIMAL(18,2),
    valid_from DATE, valid_to DATE,
    applicable_segment STRING, applicable_category STRING,
    usage_limit_per_customer INT, total_usage_limit INT,
    is_active STRING, created_date DATE,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-2111-eu-north-1/saleslake/qa/silver_delta_tables/discount/';

CREATE TABLE IF NOT EXISTS saleslake_prd.silver_prd.cleanedDiscount (
    discount_id INT, discount_code STRING, discount_name STRING,
    discount_type STRING, discount_value DECIMAL(10,2),
    min_purchase_amount DECIMAL(18,2), max_discount_amount DECIMAL(18,2),
    valid_from DATE, valid_to DATE,
    applicable_segment STRING, applicable_category STRING,
    usage_limit_per_customer INT, total_usage_limit INT,
    is_active STRING, created_date DATE,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-2111-eu-north-1/saleslake/prd/silver_delta_table/discount';

# %%
# %sql
-- drop table saleslake_dev.silver_dev.cleanedDiscount
-- drop table saleslake_qa.silver_qa.cleanedDiscount 
drop table saleslake_prd.silver_prd.cleanedDiscount

# %%
# %sql
-- ===== NEW: dim_discount  (SCD Type 2, external on AWS S3) =====
CREATE TABLE IF NOT EXISTS saleslake_dev.gold_dev.dim_discount (
    discount_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    discount_id INT, discount_code STRING, discount_name STRING,
    discount_type STRING, discount_value DECIMAL(10,2),
    min_purchase_amount DECIMAL(18,2), max_discount_amount DECIMAL(18,2),
    valid_from DATE, valid_to DATE,
    applicable_segment STRING, applicable_category STRING,
    usage_limit_per_customer INT, total_usage_limit INT, status STRING,
    is_active STRING, rec_version INT,
    start_effective_ts TIMESTAMP, end_effective_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-2111-eu-north-1/saleslake/dev/gold_delta_table/discount/dim_discount/';

CREATE TABLE IF NOT EXISTS saleslake_qa.gold_qa.dim_discount (
    discount_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    discount_id INT, discount_code STRING, discount_name STRING,
    discount_type STRING, discount_value DECIMAL(10,2),
    min_purchase_amount DECIMAL(18,2), max_discount_amount DECIMAL(18,2),
    valid_from DATE, valid_to DATE,
    applicable_segment STRING, applicable_category STRING,
    usage_limit_per_customer INT, total_usage_limit INT, status STRING,
    is_active STRING, rec_version INT,
    start_effective_ts TIMESTAMP, end_effective_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-2111-eu-north-1/saleslake/qa/gold_delta_table/discount/dim_discount/';

CREATE TABLE IF NOT EXISTS saleslake_prd.gold_prd.dim_discount (
    discount_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    discount_id INT, discount_code STRING, discount_name STRING,
    discount_type STRING, discount_value DECIMAL(10,2),
    min_purchase_amount DECIMAL(18,2), max_discount_amount DECIMAL(18,2),
    valid_from DATE, valid_to DATE,
    applicable_segment STRING, applicable_category STRING,
    usage_limit_per_customer INT, total_usage_limit INT, status STRING,
    is_active STRING, rec_version INT,
    start_effective_ts TIMESTAMP, end_effective_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-2111-eu-north-1/saleslake/prd/gold_delta_table/discount/dim_discount/';

# %%
# %sql
-- drop table saleslake_dev.gold_dev.dim_discount
-- drop table saleslake_qa.gold_qa.dim_discount 
drop table saleslake_prd.gold_prd.dim_discount

# %%
# %sql
-- ===== NEW: dim_discount  (SCD Type 2, external on AWS S3) =====
CREATE TABLE IF NOT EXISTS saleslake_dev.gold_dev.dim_discount (
    discount_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    discount_id INT, discount_code STRING, discount_name STRING,
    discount_type STRING, discount_value DECIMAL(10,2),
    min_purchase_amount DECIMAL(18,2), max_discount_amount DECIMAL(18,2),
    valid_from DATE, valid_to DATE,
    applicable_segment STRING, applicable_category STRING,
    usage_limit_per_customer INT, total_usage_limit INT, status STRING,
    is_active STRING, rec_version INT,
    start_effective_ts TIMESTAMP, end_effective_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-2111-eu-north-1/saleslake/dev/delta_tables/gold/dim_discount/';

CREATE TABLE IF NOT EXISTS saleslake_qa.gold_qa.dim_discount (
    discount_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    discount_id INT, discount_code STRING, discount_name STRING,
    discount_type STRING, discount_value DECIMAL(10,2),
    min_purchase_amount DECIMAL(18,2), max_discount_amount DECIMAL(18,2),
    valid_from DATE, valid_to DATE,
    applicable_segment STRING, applicable_category STRING,
    usage_limit_per_customer INT, total_usage_limit INT, status STRING,
    is_active STRING, rec_version INT,
    start_effective_ts TIMESTAMP, end_effective_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-2111-eu-north-1/saleslake/qa/delta_tables/gold/dim_discount/';

CREATE TABLE IF NOT EXISTS saleslake_prd.gold_prd.dim_discount (
    discount_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    discount_id INT, discount_code STRING, discount_name STRING,
    discount_type STRING, discount_value DECIMAL(10,2),
    min_purchase_amount DECIMAL(18,2), max_discount_amount DECIMAL(18,2),
    valid_from DATE, valid_to DATE,
    applicable_segment STRING, applicable_category STRING,
    usage_limit_per_customer INT, total_usage_limit INT, status STRING,
    is_active STRING, rec_version INT,
    start_effective_ts TIMESTAMP, end_effective_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-2111-eu-north-1/saleslake/prd/delta_tables/gold/dim_discount/';

# %%
# %sql
-- ===== NEW: dim_discount  (SCD Type 2, external on AWS S3) =====
CREATE TABLE IF NOT EXISTS saleslake_dev.gold_dev.dim_discount (
    discount_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    discount_id INT, discount_code STRING, discount_name STRING,
    discount_type STRING, discount_value DECIMAL(10,2),
    min_purchase_amount DECIMAL(18,2), max_discount_amount DECIMAL(18,2),
    valid_from DATE, valid_to DATE,
    applicable_segment STRING, applicable_category STRING,
    usage_limit_per_customer INT, total_usage_limit INT, status STRING,
    is_active STRING, rec_version INT,
    start_effective_ts TIMESTAMP, end_effective_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-2111-eu-north-1/saleslake/dev/gold_delta_table/discount/dim_discount/';

# %%
df_bronze = spark.read.option("header", True).option("inferSchema", True).csv("s3://saleslake-2111-eu-north-1/saleslake/dev/gold_delta_table/discount/dim_discount/discount_master.csv")

df_bronze.show()

# %%
df_bronze.write.format("delta").mode("overwrite").option("overwriteSchema", "true").save("s3://saleslake-2111-eu-north-1/saleslake/dev/delta_tables/discount/")
